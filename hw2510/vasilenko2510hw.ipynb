# %%
# %pip install -Uq wordcloud
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.3
# [notice] To update, run: C:\Users\asdsf\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import spacy as sp
from spacy.tokenizer import Tokenizer
from spacy.lang.ru import Russian
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import ru_core_news_sm
from collections import Counter
import matplotlib.pyplot as plt
% matplotlib inline
nlp = Russian()
nlp.max_length = 1800000
# Out:
# UsageError: Line magic function `%` not found.

# %%
with open('Tolstoy Aleksey Nikolaevich. Petr Pervyy - BooksCafe.Net.txt', 'r', encoding = 'utf-8') as book1:
    text1 = book1.read()

with open('Tolstoy Aleksey Nikolaevich. Zolotoy klyuchik ili priklyucheniya Buratino - BooksCafe.Net.txt', 'r', encoding = 'utf-8') as book2:
    text2 = book2.read()

with open('Tolstoy Aleksey. Aelita (Zakat Marsa) - BooksCafe.Net.txt', 'r', encoding = 'utf-8') as book3:
    text3 = book3.read()

with open('Tolstoy Aleksey. Giperboloid inzhenera Garina - BooksCafe.Net.txt', 'r', encoding = 'utf-8') as book4:
    text4 = book4.read()

with open('Tolstoy Aleksey. Graf Kaliostro - BooksCafe.Net.txt', 'r', encoding = 'utf-8') as book5:
    text5 = book5.read()

with open('Tolstoy Aleksey. Malchik s palchik - BooksCafe.Net.txt', 'r', encoding = 'utf-8') as book6:
    text6 = book6.read()

# %%
doc = nlp(text1)
words_filtered = nlp(str([token.text for token in doc if not token.is_punct and not token.is_stop]))
words_filtered



word_freq = Counter(token.text for token in words_filtered if token.is_alpha)
most_common_word = str(word_freq.most_common(20))

word_cloud = WordCloud().generate(most_common_word)

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

most_common_word
# Out:
# "[('Петр', 928), ('глаза', 362), ('сказал', 349), ('ни', 301), ('лицо', 229), ('Петра', 229), ('Алексеевич', 221), ('руки', 213), ('раз', 208), ('Василий', 197), ('человек', 196), ('Иван', 192), ('люди', 179), ('Алексашка', 172), ('день', 169), ('голову', 165), ('дело', 163), ('три', 156), ('Москве', 155), ('Наталья', 145)]"

# %%
doc = nlp(text2)
words_filtered = nlp(str([token.text for token in doc if not token.is_punct and not token.is_stop]))
words_filtered



word_freq = Counter(token.text for token in words_filtered if token.is_alpha)
most_common_word = str(word_freq.most_common(20))

word_cloud = WordCloud().generate(most_common_word)

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

most_common_word
# Out:
# "[('Буратино', 339), ('Карло', 111), ('Карабас', 100), ('Барабас', 99), ('Пьеро', 86), ('Мальвина', 51), ('Артемон', 51), ('сказал', 46), ('сказала', 38), ('нос', 36), ('Дуремар', 32), ('глаза', 30), ('ключик', 27), ('время', 26), ('хвост', 26), ('ни', 26), ('ответил', 24), ('Лиса', 24), ('начал', 23), ('Джузеппе', 22)]"

# %%
doc = nlp(text3)
words_filtered = nlp(str([token.text for token in doc if not token.is_punct and not token.is_stop]))
words_filtered



word_freq = Counter(token.text for token in words_filtered if token.is_alpha)
most_common_word = str(word_freq.most_common(20))

word_cloud = WordCloud().generate(most_common_word)

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

most_common_word
# Out:
# "[('Лось', 331), ('Гусев', 289), ('Аэлита', 106), ('глаза', 92), ('сказал', 92), ('неба', 62), ('руки', 61), ('лицо', 56), ('Лося', 55), ('земли', 53), ('время', 52), ('Мстислав', 49), ('Сергеевич', 49), ('голову', 46), ('глядел', 38), ('ни', 37), ('города', 36), ('сел', 34), ('город', 34), ('земле', 33)]"

# %%
doc = nlp(text4)
words_filtered = nlp(str([token.text for token in doc if not token.is_punct and not token.is_stop]))
words_filtered



word_freq = Counter(token.text for token in words_filtered if token.is_alpha)
most_common_word = str(word_freq.most_common(20))

word_cloud = WordCloud().generate(most_common_word)

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

most_common_word
# Out:
# "[('Гарин', 369), ('Роллинг', 296), ('Шельга', 230), ('Зоя', 224), ('сказал', 181), ('Гарина', 144), ('человек', 113), ('Янсен', 110), ('Роллинга', 98), ('глаза', 92), ('ни', 92), ('Ламоль', 80), ('Вольф', 74), ('время', 73), ('лицо', 70), ('руку', 70), ('Хлынов', 67), ('мадам', 65), ('Тарашкин', 64), ('руки', 56)]"

# %%
doc = nlp(text5)
words_filtered = nlp(str([token.text for token in doc if not token.is_punct and not token.is_stop]))
words_filtered



word_freq = Counter(token.text for token in words_filtered if token.is_alpha)
most_common_word = str(word_freq.most_common(20))

word_cloud = WordCloud().generate(most_common_word)

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

most_common_word
# Out:
# "[('Алексей', 113), ('Алексеевич', 113), ('Калиостро', 59), ('Мария', 31), ('руку', 22), ('глаза', 21), ('Федосья', 18), ('Ивановна', 18), ('Алексея', 18), ('Алексеевича', 18), ('время', 17), ('лицо', 17), ('сказал', 16), ('тетушка', 15), ('ни', 15), ('Прасковья', 14), ('портрет', 14), ('Прасковьи', 14), ('Павловны', 14), ('Павловна', 13)]"

# %%
doc = nlp(text6)
words_filtered = nlp(str([token.text for token in doc if not token.is_punct and not token.is_stop]))
words_filtered



word_freq = Counter(token.text for token in words_filtered if token.is_alpha)
most_common_word = str(word_freq.most_common(20))

word_cloud = WordCloud().generate(most_common_word)

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

most_common_word
# Out:
# "[('пальчик', 9), ('Мальчик', 8), ('волк', 5), ('старуха', 4), ('мальчик', 4), ('старик', 3), ('говорит', 3), ('батюшка', 3), ('домой', 3), ('волка', 3), ('тряпку', 2), ('сынок', 2), ('смотрит', 2), ('крохотный', 2), ('пашню', 2), ('помогать', 2), ('Пришел', 2), ('пахать', 2), ('отцу', 2), ('Старик', 2)]"
